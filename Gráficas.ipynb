# %%
# %pylab inline
from random import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #Manejo Básico

# %%
#Arreglos para probar
x = linspace(0,10, 20)
y = x**2
z = x**3

# %%
rcdefaults()
figura1 = figure(figsize=(10,5))
subplot2grid((1,2), (0,0), colspan=1) #Crear varias gŕaficas
#Cada gŕafica se identifica con su label.
plot(x, y, 'r--o', label = "Puntos")
plot(x, y*1.3, 'bs', label =  "Cuadrados")
plot(x, y*1.7, 'g^-', label = "Triángulos")
plot(x, y*2, 'g*--', lw = 2,label = "Estrellas", ms = 12, color = "Purple")
plot(x, y*2.5, 'v', color = "Yellow", ms = 7, label = "Nabla")
title("La Cuadrática")
legend(bbox_to_anchor=(0.7,1))
xlabel("X")
ylabel("Y")

with xkcd(): #Usar ese estilo XKDC.
    subplot2grid((1,2), (0,1), colspan=1)
    #Probar estilos
    plot(x, y, 'r--o', label = "Puntos")
    plot(x, y*1.3, 'bs', label =  "Cuadrados")
    plot(x, y*1.7, 'g^-', label = "Triángulos")
    plot(x, y*2, 'g*--', lw = 2,label = "Estrellas", ms = 12, color = "Purple")
    plot(x, y*2.5, 'v', color = "Yellow", ms = 7, label = "Nabla")
title(u"Estilo Cómico")
legend(bbox_to_anchor=(0.7,1))
xlabel("X")
ylabel("Y")
rcdefaults() #Volver a estilo estándar
show()
# Out:
# /home/juan/anaconda3/lib/python3.4/site-packages/matplotlib/font_manager.py:1282: UserWarning: findfont: Font family ['Humor Sans', 'Comic Sans MS'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# **Símbolos:** http://matplotlib.org/api/markers_api.html
#
# **Leyendas:** http://matplotlib.org/users/legend_guide.html#legend-location
#
# **Scatter:** http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter

# %% [markdown]
# ##Otras Formas de Mostrar Datos

# %%
figure(figsize=(15,5))
subplot2grid((1,3), (0,0)) #Primer scatter plot
scatter(x,y, label = "Datos")
title("Simple")
legend(loc = 'upper left')
ylim(0, 120)
xlim(0,12)
xlabel("X")
ylabel("Y")

#Crear errores aleatorios pero pequeños
error = []
for i in range(20):
    actual = uniform(0,7)
    error.append(actual)

subplot2grid((1,3), (0,1))
colores = rand(10)
area = np.pi * (10*colores)**2 #Distintos tamaños
plot(x,y*1.4+10,'o--',label="Datos", markerfacecolor = "Red", markeredgecolor = "Blue", ms = 5, markeredgewidth = 1)
errorbar(x,y*1.4+10,yerr=error, ls="-o", lw = 2) #Barras de Error
title("Estética Mejorada")
ylim(0,160)
xlim(0,12)
xlabel("X")
ylabel("Y")
legend(loc = "upper left")
grid(True)

xkcd()
subplot2grid((1,3), (0,2))
scatter(x,y,marker='*', s = area, c = "Green")
title("Experimentando")
ylim(0,120)
xlim(0,12)
xlabel("X")
ylabel("Y")
grid(True)
rcdefaults()
show()
# Out:
# /home/juan/anaconda3/lib/python3.4/site-packages/matplotlib/font_manager.py:1282: UserWarning: findfont: Font family ['Humor Sans', 'Comic Sans MS'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# #Visualizaciones

# %% [markdown]
# Todos los tipos de gráficos disponibles se pueden encontrar en este link: http://matplotlib.org/gallery.html
#
# https://github.com/jrjohansson/scientific-python-lectures/blob/master/Lecture-4-Matplotlib.ipynb

# %%
n = array([0,1,2,3,4,5]) #Arreglo de prueba nuevo
x2 = linspace(0,1,1000)
y2 = sin(4 * np.pi * x2) * exp(-5 * x2)

# %%
figure(figsize=(15,13))
subplot2grid((2,3), (0,0))
bar(n, n**2, align="center", width=0.5, alpha=0.5)
xlim(0,6)
title("Diagrama de Barras")
xlabel("n")
ylabel("$n^2$")

subplot2grid((2,3), (0,1))
step(n, n**2, lw=2)
title("Diagrama escalonado")
xlabel("n")
ylabel("$n^2$")

subplot2grid((2,3), (0,2))
fill_between(n, n**2, n**3, color="Blue", alpha=0.5)
title("Área entre Curvas")

subplot2grid((2,3), (1,0))
fill(x2,y2)

subplot2grid((2,3),(1,1))
Y, X = np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X + Y**2
V = 1 + X**2 - Y
speed = np.sqrt(U**2 + V**2)

streamplot(X, Y, U, V, color=U, linewidth=2, cmap='gist_heat')
colorbar()
title("Diagrama de Posición\n según velocidades")
show()

# %% [markdown]
# #Ahora en 3D

# %% [markdown]
# Lo más interesante: https://github.com/jrjohansson/scientific-python-lectures/blob/master/Lecture-4-Matplotlib.ipynb

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
#Definir mi figura para trabajar en 2d
t = linspace(0,100,1000).T
x = 40*sin(t)
y = 40*cos(t)

# %%
X,Y = meshgrid(x, y)

# %%
# Una curva paramétrica
fig = figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,t)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
title("3D")
show()

# %%
#Tomando el notebook de Juan David Lizarazo y haciendo pequeñas añadiduras.
x=linspace(-4*pi,4*pi,100)
y=linspace(-4*pi,4*pi,100)
xg, yg = meshgrid(x,y)
fig=figure(figsize=(20,10))
ax=fig.gca(projection='3d')
R = sqrt(xg**2 + yg**2)
zg = sin(R)
mapa = "gist_heat"
surf = ax.plot_surface(xg, yg, zg, rstride=1, cstride=1, cmap=mapa,linewidth=0, antialiased=True)
ax.set_zlim(-3.0, 3.0)
ax.set_xlim(-20, 20)
ax.set_ylim(-20, 20)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

cset = ax.contour(xg, yg, zg, zdir='z', offset=-3, cmap=mapa)
cset = ax.contour(xg, yg, zg, zdir='x', offset=-20, cmap=mapa)
cset = ax.contour(xg, yg, zg, zdir='y', offset=-20, cmap=mapa)

title("Pruebas Estéticas\n")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.view_init(30, 45)
blue_proxy = plt.Rectangle((0, 0), 1, 1, fc="Orange")
ax.legend([blue_proxy],['La Función'])
savefig("3D.png")
show()
